# %%
# Import libraries
import os
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers, models
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Import libraries
#       2 import os
#       3 import numpy as np
# ----> 4 from tensorflow.keras.datasets import mnist
#       5 from tensorflow.keras import layers, models
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Load dataset (auto-downloads first time)
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Create folder in current working directory
save_dir = "mnist_data"
os.makedirs(save_dir, exist_ok=True)
# Save arrays as .npy files
np.save(os.path.join(save_dir, "X_train.npy"), X_train)
np.save(os.path.join(save_dir, "y_train.npy"), y_train)
np.save(os.path.join(save_dir, "X_test.npy"), X_test)
np.save(os.path.join(save_dir, "y_test.npy"), y_test)
print("MNIST dataset saved in folder:", save_dir)
